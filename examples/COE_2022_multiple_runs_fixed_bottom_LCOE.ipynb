# %% [markdown]
# # 2022 COE Review Fixed-bottom LCOE Working Analysis
#
# If you want to run this notebook, keep in mind that the library path from the FLORIS config file has to be changed accordingly to your new path

# %% [markdown]
# ## Imports and environment set up

# %%
from pathlib import Path
from itertools import product

import pandas as pd
import matplotlib.pyplot as plt

from whale import Project
from whale.utilities import load_yaml

pd.options.display.float_format = '{:,.4f}'.format
pd.options.display.max_columns = 100
pd.options.display.max_rows = 100

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Function to Extract Results

# %%
def extract_results(project_name):  # Run the project and clean up the logging
    #project_name = "UMaine_catenary"
    library_path = Path("library").resolve()
    
    metrics_configuration = {
        "# Turbines": {"metric": "n_turbines", "kwargs": {}},
        "Turbine Rating (MW)": {"metric": "turbine_rating", "kwargs": {}},
        "Project Capacity (MW)": {"metric": "capacity", "kwargs": {"units": "mw"}},
        "# OSS": {"metric": "n_substations", "kwargs": {}},
        "Total Export Cable Length (km)": {"metric": "export_system_total_cable_length", "kwargs": {}},
        "Total Array Cable Length (km)": {"metric": "array_system_total_cable_length", "kwargs": {}},
        "CapEx ($)": {"metric": "capex", "kwargs": {}},
        "CapEx per kW ($/kW)": {"metric": "capex", "kwargs": {"per_capacity": "kw"}},
        "OpEx ($)": {"metric": "opex", "kwargs": {}},
        "OpEx per kW ($/kW)": {"metric": "opex", "kwargs": {"per_capacity": "kw"}},
        "AEP (MWh)": {
            "metric": "energy_production",
            "kwargs": {"units": "mw", "aep": True, "with_losses": True}
        },
        "AEP per kW (MWh/kW)": {
            "metric": "energy_production",
            "kwargs": {"units": "mw", "per_capacity": "kw", "aep": True, "with_losses": True}
        },
        "Net Capacity Factor Without Unmodeled Losses (%)": {
            "metric": "capacity_factor",
            "kwargs": {"which": "net"}
        },
        "Net Capacity Factor With All Losses (%)": {
            "metric": "capacity_factor",
            "kwargs": {"which": "net", "with_losses": True}
        },
        "Gross Capacity Factor (%)": {"metric": "capacity_factor", "kwargs": {"which": "gross"}},
        "Energy Availability (%)": {"metric": "availability", "kwargs": {"which": "energy"}},
        "LCOE ($/MWh)": {"metric": "lcoe", "kwargs": {}},
        "IRR (%)": {"metric": "irr", "kwargs": {}},
        "NPV ($)": {"metric": "npv", "kwargs": {}},
    }

    metrics_order = [
        "# Turbines",
        "Turbine Rating (MW)",
        "Project Capacity (MW)",
        "# OSS",
        "Total Export Cable Length (km)",
        "Total Array Cable Length (km)",
        "FCR (%)",
        "Offtake Price ($/MWh)",
        "CapEx ($)",
        "CapEx per kW ($/kW)",
        "System CapEx for Export Cables ($)",
        "Installation CapEx for Export Cables ($)",
        "CapEx Without Export Cables ($)",
        "OpEx ($)",
        "OpEx per kW ($/kW)",
        "Annual OpEx per kW ($/kW)",
        "Energy Availability (%)",
        "Gross Capacity Factor (%)",
        "Net Capacity Factor Without Unmodeled Losses (%)",
        "Net Capacity Factor With All Losses (%)",
        "AEP (MWh)",
        "AEP per kW (MWh/kW)",
        "LCOE ($/MWh)",
        "IRR (%)",
        "NPV ($)",
    ]
    final_cols = ["CapEx ($)", "OpEx ($)", "Energy Production (GWh)", "Revenue ($)", "Cash Flow ($)"]
    
    config = load_yaml(
        library_path / "project/config",
        f"{project_name.replace(' ', '_')}_base.yaml"
    )
    project = Project(
        # Basic Model Configurations
        library_path=library_path,
        #weather_profile=library_path / "weather" / "ocean_wind_1_39.0_-74.0_1959_2023.csv",
        connect_floris_to_layout=True,
        connect_orbit_array_design=True,
        **config,
    )

    
    project.run(
        which_floris="wind_rose",
        full_wind_rose=False,
        floris_reinitialize_kwargs=dict(cut_in_wind_speed=3.0, cut_out_wind_speed=25.0)
    )
    project.wombat.env.cleanup_log_files()  # Delete logging data from WOMBAT
    
    #fig, ax = project.plot_farm(return_fig=True)
    
    # Gather the high-level results
    report_df = project.generate_report(metrics_configuration, project_name).T
    export_system = project.orbit.system_costs["ExportCableInstallation"]
    export_installation = project.orbit.installation_costs["ExportCableInstallation"]
    capex_sans_export = project.orbit.total_capex - export_system - export_installation
    additional_reporting = pd.DataFrame(
        [
            ["FCR (%)", project.fixed_charge_rate],
            ["Offtake Price ($/MWh)", project.offtake_price],
            ["System CapEx for Export Cables ($)", export_system],
            ["Installation CapEx for Export Cables ($)", export_installation],
            ["CapEx Without Export Cables ($)", capex_sans_export],
            ["Annual OpEx per kW ($/kW)", report_df.loc["OpEx per kW ($/kW)", project_name] / project.operations_years],
        ],
        columns=["Project"] + report_df.columns.tolist(),
    ).set_index("Project")
    report_df = pd.concat((report_df, additional_reporting), axis=0).loc[metrics_order]

    # Gather the detailed results
    monthly_results = project.cash_flow(breakdown=True).join(project.energy_production(frequency="month-year")).fillna(0)
    monthly_results = monthly_results.assign(
        CapEx_Installation=monthly_results[[c for c in monthly_results if c.startswith("CapEx") and c.endswith("Installation")]].sum(axis=1),
        CapEx_System=monthly_results[[c for c in monthly_results if c.startswith("CapEx") and c.endswith("System")]].sum(axis=1),
    )

    # monthly_results.to_csv(library_path / "results" / f"{project_name.lower().replace(' ', '_')}_monthly_detailed_results.csv")
    monthly_results["CapEx ($)"] = monthly_results[["CapEx_Installation", "CapEx_Soft", "CapEx_Project", "CapEx_System", "CapEx_Turbine"]].sum(axis=1)
    monthly_results = monthly_results.rename(columns={"OpEx": "OpEx ($)","Revenue": "Revenue ($)", "cash_flow": "Cash Flow ($)"})[final_cols]

    if "ExportSystemDesign" in project.orbit._phases:
        export = "ExportSystemDesign"
    else:
        export = "ElectricalDesign"

    # Create the inputs data
    inputs = pd.DataFrame(
        [
            ["FCR", project.fixed_charge_rate],
            ["Discount rate (%)", project.discount_rate],
            ["# Turbines", project.n_turbines()],
            ["Turbine Rating (MW)", project.turbine_rating()],
            ["Project Capacity (MW)", project.capacity("mw")],
            ["# OSS", project.n_substations()],
            ["Substructure type", "??"],
            ["Row spacing (rotor diameters)", "not used for custom layouts"],
            ["Turbine spacing (rotor diameters)", "not used for custom layouts"],
            ["Depth (m)", project.orbit.config["site"]["depth"]],
            [
                "Mean wind speed (m/s)",
                project.weather.loc[
                    project.orbit_start_date: project.wombat.env.end_datetime,
                    "windspeed_100m"
                ].mean()
            ],
            ["Distance to landfall (km)", project.orbit.config["site"]["distance_to_landfall"]],
            ["Distance to port (km)", project.wombat.config.port_distance],
            ["Interconnection distance (km)", project.orbit._phases[export]._distance_to_interconnection],
            ["# of POIs", "??"],
            ["Export cable type", [*project.orbit._phases[export].cable_lengths_by_type]],
            ["Array cable type", [*project.orbit._phases["CustomArraySystemDesign"].cable_lengths_by_type]],
        ],
        columns=["Inputs", f"{project_name}"]
    ).set_index("Inputs")

    # Save the outputs
    report_df.index.name = "Metrics"
    wrong_indexes = ["Offtake Price ($/MWh)", "System CapEx for Export Cables ($)", "Installation CapEx for Export Cables ($)", "CapEx Without Export Cables ($)", "IRR (%)", "NPV ($)"]
    
    
    return report_df.drop(wrong_indexes,axis=0)

# %% [markdown]
# # Extract AEP and OpEx Outputs - Multiple Runs
# Availability and OpEx varies depending on the run as it uses probabilistic functions, so we collect the data from 5 runs and calculate the average OpEx and AEP

# %%
def display_results_all_runs(n_runs):
    import pandas as pd
    
    df_list_fixed_bottom = list()
    df_list_GF_fixed_bottom = list()
    df_final_list = list()
    
    for i in range(0,n_runs):
        df_1 = extract_results("COE_2022_GF_fixed_bottom")
        #display(df_1)
        #final_df = pd.concat(df_final_list, axis=1)
        
        if i == 0:
            df_list_GF_fixed_bottom = df_1
            #display(df_list_catenary)
        else:
            df_list_GF_fixed_bottom = pd.concat([df_list_GF_fixed_bottom, df_1], axis=1)
            #display(df_list_catenary)
            
            
    for i in range(0,n_runs):
        df_2 = extract_results("COE_2022_fixed_bottom")
        #display(df_2)
        #final_df = pd.concat(df_final_list, axis=1)
        
        if i == 0:
            df_list_fixed_bottom = df_2
            #display(df_list_semitaut)
        else:
            df_list_fixed_bottom = pd.concat([df_list_fixed_bottom, df_2], axis=1)
            #display(df_list_semitaut)      
            
    
    final_df = pd.concat([df_list_fixed_bottom, df_list_GF_fixed_bottom], axis=1)
    
    return final_df

summary_results = display_results_all_runs(10)
# Out:
# ORBIT library intialized at 'C:\COWER\WHaLE\examples\library'
# UserWarning: C:\COWER\ORBIT\ORBIT\phases\design\array_system_design.py:906
# Missing data in columns ['bury_speed']; all values will be calculated.UserWarning: C:\COWER\ORBIT\ORBIT\phases\design\array_system_design.py:906
# Missing data in columns ['bury_speed']; all values will be calculated.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# Correcting negative Overhang:-2.5
# Correcting negative Overhang:-2.5
# Correcting negative Overhang:-2.5
# FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# Correcting negative Overhang:-2.5
# Correcting negative Overhang:-2.5
# Correcting negative Overhang:-2.5
# FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# Correcting negative Overhang:-2.5
# Correcting negative Overhang:-2.5
# Correcting negative Overhang:-2.5
# Correcting negative Overhang:-2.5
# Correcting negative Overhang:-2.5
# Correcting negative Overhang:-2.5
# FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# Correcting negative Overhang:-2.5
# FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.UserWarning: C:\COWER\ORBIT\ORBIT\phases\design\array_system_design.py:906
# Missing data in columns ['bury_speed']; all values will be calculated.UserWarning: C:\COWER\ORBIT\ORBIT\phases\design\array_system_design.py:906
# Missing data in columns ['bury_speed']; all values will be calculated.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# Correcting negative Overhang:-2.5
# Correcting negative Overhang:-2.5
# Correcting negative Overhang:-2.5
# FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# Correcting negative Overhang:-2.5
# Correcting negative Overhang:-2.5
# Correcting negative Overhang:-2.5
# FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# Correcting negative Overhang:-2.5
# Correcting negative Overhang:-2.5
# Correcting negative Overhang:-2.5
# FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# Correcting negative Overhang:-2.5
# Correcting negative Overhang:-2.5
# Correcting negative Overhang:-2.5
# Correcting negative Overhang:-2.5
# FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.UserWarning: C:\COWER\ORBIT\ORBIT\phases\design\array_system_design.py:906
# Missing data in columns ['bury_speed']; all values will be calculated.UserWarning: C:\COWER\ORBIT\ORBIT\phases\design\array_system_design.py:906
# Missing data in columns ['bury_speed']; all values will be calculated.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# Correcting negative Overhang:-2.5
# Correcting negative Overhang:-2.5
# Correcting negative Overhang:-2.5
# FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# Correcting negative Overhang:-2.5
# Correcting negative Overhang:-2.5
# Correcting negative Overhang:-2.5
# FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# Correcting negative Overhang:-2.5
# Correcting negative Overhang:-2.5
# Correcting negative Overhang:-2.5
# FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# Correcting negative Overhang:-2.5
# Correcting negative Overhang:-2.5
# Correcting negative Overhang:-2.5
# FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# Correcting negative Overhang:-2.5
# UserWarning: C:\COWER\ORBIT\ORBIT\phases\design\array_system_design.py:906
# Missing data in columns ['bury_speed']; all values will be calculated.UserWarning: C:\COWER\ORBIT\ORBIT\phases\design\array_system_design.py:906
# Missing data in columns ['bury_speed']; all values will be calculated.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# Correcting negative Overhang:-2.5
# Correcting negative Overhang:-2.5
# Correcting negative Overhang:-2.5
# FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# Correcting negative Overhang:-2.5
# Correcting negative Overhang:-2.5
# Correcting negative Overhang:-2.5
# FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# Correcting negative Overhang:-2.5
# Correcting negative Overhang:-2.5
# Correcting negative Overhang:-2.5
# FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# Correcting negative Overhang:-2.5
# Correcting negative Overhang:-2.5
# Correcting negative Overhang:-2.5
# FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# Correcting negative Overhang:-2.5
# UserWarning: C:\COWER\ORBIT\ORBIT\phases\design\array_system_design.py:906
# Missing data in columns ['bury_speed']; all values will be calculated.UserWarning: C:\COWER\ORBIT\ORBIT\phases\design\array_system_design.py:906
# Missing data in columns ['bury_speed']; all values will be calculated.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# Correcting negative Overhang:-2.5
# Correcting negative Overhang:-2.5
# Correcting negative Overhang:-2.5
# FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# Correcting negative Overhang:-2.5
# Correcting negative Overhang:-2.5
# Correcting negative Overhang:-2.5
# Correcting negative Overhang:-2.5
# FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# Correcting negative Overhang:-2.5
# Correcting negative Overhang:-2.5
# Correcting negative Overhang:-2.5
# FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# Correcting negative Overhang:-2.5
# Correcting negative Overhang:-2.5
# Correcting negative Overhang:-2.5
# FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.UserWarning: C:\COWER\ORBIT\ORBIT\phases\design\array_system_design.py:906
# Missing data in columns ['bury_speed']; all values will be calculated.UserWarning: C:\COWER\ORBIT\ORBIT\phases\design\array_system_design.py:906
# Missing data in columns ['bury_speed']; all values will be calculated.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# Correcting negative Overhang:-2.5
# Correcting negative Overhang:-2.5
# Correcting negative Overhang:-2.5
# FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# Correcting negative Overhang:-2.5
# Correcting negative Overhang:-2.5
# Correcting negative Overhang:-2.5
# FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# Correcting negative Overhang:-2.5
# Correcting negative Overhang:-2.5
# Correcting negative Overhang:-2.5
# FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# Correcting negative Overhang:-2.5
# Correcting negative Overhang:-2.5
# Correcting negative Overhang:-2.5
# FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# ...
# Missing data in columns ['bury_speed']; all values will be calculated.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# Correcting negative Overhang:-2.5
# Correcting negative Overhang:-2.5
# FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# Correcting negative Overhang:-2.5
# Correcting negative Overhang:-2.5
# FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# Correcting negative Overhang:-2.5
# Correcting negative Overhang:-2.5
# FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# Correcting negative Overhang:-2.5
# Correcting negative Overhang:-2.5
# FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# Correcting negative Overhang:-2.5
# Correcting negative Overhang:-2.5
# FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# Correcting negative Overhang:-2.5
# Correcting negative Overhang:-2.5
# FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# Correcting negative Overhang:-2.5
# UserWarning: C:\COWER\ORBIT\ORBIT\phases\design\array_system_design.py:906
# Missing data in columns ['bury_speed']; all values will be calculated.UserWarning: C:\COWER\ORBIT\ORBIT\phases\design\array_system_design.py:906
# Missing data in columns ['bury_speed']; all values will be calculated.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# Correcting negative Overhang:-2.5
# Correcting negative Overhang:-2.5
# FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# Correcting negative Overhang:-2.5
# Correcting negative Overhang:-2.5
# FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# Correcting negative Overhang:-2.5
# Correcting negative Overhang:-2.5
# FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# Correcting negative Overhang:-2.5
# Correcting negative Overhang:-2.5
# FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# Correcting negative Overhang:-2.5
# Correcting negative Overhang:-2.5
# FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# Correcting negative Overhang:-2.5
# Correcting negative Overhang:-2.5
# FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:165
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.FutureWarning: C:\COWER\floris\floris\tools\wind_rose.py:264
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# Correcting negative Overhang:-2.5

# %%
display(summary_results)
# Out:
#                                                   COE_2022_fixed_bottom  \
# Metrics
# # Turbines                                                      50.0000
# Turbine Rating (MW)                                             12.0000
# Project Capacity (MW)                                          600.0000
# # OSS                                                            1.0000
# Total Export Cable Length (km)                                 118.0680
# Total Array Cable Length (km)                                  277.9831
# FCR (%)                                                          0.0569
# CapEx ($)                                            2,164,241,481.8991
# CapEx per kW ($/kW)                                          3,607.0691
# OpEx ($)                                             1,156,471,639.8128
# OpEx per kW ($/kW)                                           1,927.4527
# Annual OpEx per kW ($/kW)                                       91.7835
# Energy Availability (%)                                          0.9334
# Gross Capacity Factor (%)                                        0.4896
# Net Capacity Factor Without Unmodeled Losses (%)                 0.4570
# Net Capacity Factor With All Losses (%)                          0.4081
# AEP (MWh)                                                2,146,454.6459
# AEP per kW (MWh/kW)                                              3.5774
# LCOE ($/MWh)                                                    83.0278
#
#                                                   COE_2022_fixed_bottom  \
# Metrics
# # Turbines                                                      50.0000
# Turbine Rating (MW)                                             12.0000
# Project Capacity (MW)                                          600.0000
# # OSS                                                            1.0000
# Total Export Cable Length (km)                                 118.0680
# Total Array Cable Length (km)                                  277.9831
# FCR (%)                                                          0.0569
# CapEx ($)                                            2,164,241,481.8991
# CapEx per kW ($/kW)                                          3,607.0691
# OpEx ($)                                             1,132,064,371.2453
# OpEx per kW ($/kW)                                           1,886.7740
# Annual OpEx per kW ($/kW)                                       89.8464
# Energy Availability (%)                                          0.9343
# Gross Capacity Factor (%)                                        0.4896
# Net Capacity Factor Without Unmodeled Losses (%)                 0.4573
# Net Capacity Factor With All Losses (%)                          0.4083
# AEP (MWh)                                                2,147,913.3603
# AEP per kW (MWh/kW)                                              3.5799
# LCOE ($/MWh)                                                    82.4303
#
#                                                   COE_2022_fixed_bottom  \
# Metrics
# # Turbines                                                      50.0000
# Turbine Rating (MW)                                             12.0000
# Project Capacity (MW)                                          600.0000
# # OSS                                                            1.0000
# Total Export Cable Length (km)                                 118.0680
# Total Array Cable Length (km)                                  277.9831
# FCR (%)                                                          0.0569
# CapEx ($)                                            2,164,241,481.8991
# CapEx per kW ($/kW)                                          3,607.0691
# OpEx ($)                                             1,164,818,462.1834
# OpEx per kW ($/kW)                                           1,941.3641
# Annual OpEx per kW ($/kW)                                       92.4459
# Energy Availability (%)                                          0.9357
# Gross Capacity Factor (%)                                        0.4896
# Net Capacity Factor Without Unmodeled Losses (%)                 0.4582
# Net Capacity Factor With All Losses (%)                          0.4092
# AEP (MWh)                                                2,152,612.3520
# AEP per kW (MWh/kW)                                              3.5877
# LCOE ($/MWh)                                                    82.9749
#
#                                                   COE_2022_fixed_bottom  \
# Metrics
# # Turbines                                                      50.0000
# Turbine Rating (MW)                                             12.0000
# Project Capacity (MW)                                          600.0000
# # OSS                                                            1.0000
# Total Export Cable Length (km)                                 118.0680
# Total Array Cable Length (km)                                  277.9831
# FCR (%)                                                          0.0569
# CapEx ($)                                            2,164,241,481.8991
# CapEx per kW ($/kW)                                          3,607.0691
# OpEx ($)                                             1,085,350,850.7914
# OpEx per kW ($/kW)                                           1,808.9181
# Annual OpEx per kW ($/kW)                                       86.1390
# Energy Availability (%)                                          0.9347
# Gross Capacity Factor (%)                                        0.4896
# Net Capacity Factor Without Unmodeled Losses (%)                 0.4576
# Net Capacity Factor With All Losses (%)                          0.4087
# AEP (MWh)                                                2,149,689.3872
# AEP per kW (MWh/kW)                                              3.5828
# LCOE ($/MWh)                                                    81.3274
#
#                                                   COE_2022_fixed_bottom  \
# Metrics
# # Turbines                                                      50.0000
# Turbine Rating (MW)                                             12.0000
# Project Capacity (MW)                                          600.0000
# # OSS                                                            1.0000
# Total Export Cable Length (km)                                 118.0680
# Total Array Cable Length (km)                                  277.9831
# FCR (%)                                                          0.0569
# CapEx ($)                                            2,164,241,481.8991
# CapEx per kW ($/kW)                                          3,607.0691
# OpEx ($)                                             1,209,856,580.7782
# OpEx per kW ($/kW)                                           2,016.4276
# Annual OpEx per kW ($/kW)                                       96.0204
# Energy Availability (%)                                          0.9323
# Gross Capacity Factor (%)                                        0.4896
# Net Capacity Factor Without Unmodeled Losses (%)                 0.4565
# Net Capacity Factor With All Losses (%)                          0.4075
# AEP (MWh)                                                2,143,587.0030
# AEP per kW (MWh/kW)                                              3.5726
# LCOE ($/MWh)                                                    84.3248
#
#                                                   COE_2022_fixed_bottom  \
# Metrics
# # Turbines                                                      50.0000
# Turbine Rating (MW)                                             12.0000
# Project Capacity (MW)                                          600.0000
# # OSS                                                            1.0000
# Total Export Cable Length (km)                                 118.0680
# Total Array Cable Length (km)                                  277.9831
# FCR (%)                                                          0.0569
# CapEx ($)                                            2,164,241,481.8991
# CapEx per kW ($/kW)                                          3,607.0691
# OpEx ($)                                             1,029,285,649.5010
# OpEx per kW ($/kW)                                           1,715.4761
# Annual OpEx per kW ($/kW)                                       81.6893
# Energy Availability (%)                                          0.9363
# Gross Capacity Factor (%)                                        0.4896
# Net Capacity Factor Without Unmodeled Losses (%)                 0.4584
# Net Capacity Factor With All Losses (%)                          0.4094
# AEP (MWh)                                                2,153,658.9671
# AEP per kW (MWh/kW)                                              3.5894
# LCOE ($/MWh)                                                    79.9379
#
#                                                   COE_2022_fixed_bottom  \
# Metrics
# # Turbines                                                      50.0000
# Turbine Rating (MW)                                             12.0000
# Project Capacity (MW)                                          600.0000
# # OSS                                                            1.0000
# Total Export Cable Length (km)                                 118.0680
# Total Array Cable Length (km)                                  277.9831
# FCR (%)                                                          0.0569
# CapEx ($)                                            2,164,241,481.8991
# CapEx per kW ($/kW)                                          3,607.0691
# OpEx ($)                                             1,249,591,828.9070
# OpEx per kW ($/kW)                                           2,082.6530
# Annual OpEx per kW ($/kW)                                       99.1740
# Energy Availability (%)                                          0.9324
# Gross Capacity Factor (%)                                        0.4896
# Net Capacity Factor Without Unmodeled Losses (%)                 0.4564
# Net Capacity Factor With All Losses (%)                          0.4075
# AEP (MWh)                                                2,143,269.8192
# AEP per kW (MWh/kW)                                              3.5721
# LCOE ($/MWh)                                                    85.2201
#
#                                                   COE_2022_fixed_bottom  \
# Metrics
# # Turbines                                                      50.0000
# Turbine Rating (MW)                                             12.0000
# Project Capacity (MW)                                          600.0000
# # OSS                                                            1.0000
# Total Export Cable Length (km)                                 118.0680
# Total Array Cable Length (km)                                  277.9831
# FCR (%)                                                          0.0569
# CapEx ($)                                            2,164,241,481.8991
# CapEx per kW ($/kW)                                          3,607.0691
# OpEx ($)                                             1,123,090,146.6228
# OpEx per kW ($/kW)                                           1,871.8169
# Annual OpEx per kW ($/kW)                                       89.1341
# Energy Availability (%)                                          0.9349
# Gross Capacity Factor (%)                                        0.4896
# Net Capacity Factor Without Unmodeled Losses (%)                 0.4577
# Net Capacity Factor With All Losses (%)                          0.4088
# AEP (MWh)                                                2,150,151.2200
# AEP per kW (MWh/kW)                                              3.5836
# LCOE ($/MWh)                                                    82.1458
#
#                                                   COE_2022_fixed_bottom  \
# Metrics
# # Turbines                                                      50.0000
# Turbine Rating (MW)                                             12.0000
# Project Capacity (MW)                                          600.0000
# # OSS                                                            1.0000
# Total Export Cable Length (km)                                 118.0680
# Total Array Cable Length (km)                                  277.9831
# FCR (%)                                                          0.0569
# CapEx ($)                                            2,164,241,481.8991
# CapEx per kW ($/kW)                                          3,607.0691
# OpEx ($)                                             1,084,334,023.8706
# OpEx per kW ($/kW)                                           1,807.2234
# Annual OpEx per kW ($/kW)                                       86.0583
# Energy Availability (%)                                          0.9357
# Gross Capacity Factor (%)                                        0.4896
# Net Capacity Factor Without Unmodeled Losses (%)                 0.4581
# Net Capacity Factor With All Losses (%)                          0.4091
# AEP (MWh)                                                2,152,108.0279
# AEP per kW (MWh/kW)                                              3.5868
# LCOE ($/MWh)                                                    81.2135
#
#                                                   COE_2022_fixed_bottom  \
# Metrics
# # Turbines                                                      50.0000
# Turbine Rating (MW)                                             12.0000
# Project Capacity (MW)                                          600.0000
# # OSS                                                            1.0000
# Total Export Cable Length (km)                                 118.0680
# Total Array Cable Length (km)                                  277.9831
# FCR (%)                                                          0.0569
# CapEx ($)                                            2,164,241,481.8991
# CapEx per kW ($/kW)                                          3,607.0691
# OpEx ($)                                             1,223,325,432.3089
# OpEx per kW ($/kW)                                           2,038.8757
# Annual OpEx per kW ($/kW)                                       97.0893
# Energy Availability (%)                                          0.9333
# Gross Capacity Factor (%)                                        0.4896
# Net Capacity Factor Without Unmodeled Losses (%)                 0.4570
# Net Capacity Factor With All Losses (%)                          0.4080
# AEP (MWh)                                                2,146,111.3223
# AEP per kW (MWh/kW)                                              3.5769
# LCOE ($/MWh)                                                    84.5245
#
#                                                   COE_2022_GF_fixed_bottom  \
# Metrics
# # Turbines                                                         50.0000
# Turbine Rating (MW)                                                12.0000
# Project Capacity (MW)                                             600.0000
# # OSS                                                               1.0000
# Total Export Cable Length (km)                                    118.0680
# Total Array Cable Length (km)                                     277.9831
# FCR (%)                                                             0.0648
# CapEx ($)                                               2,337,324,988.5180
# CapEx per kW ($/kW)                                             3,895.5416
# OpEx ($)                                                1,183,825,045.2721
# OpEx per kW ($/kW)                                              1,973.0417
# Annual OpEx per kW ($/kW)                                          93.9544
# Energy Availability (%)                                             0.9346
# Gross Capacity Factor (%)                                           0.4896
# Net Capacity Factor Without Unmodeled Losses (%)                    0.4576
# Net Capacity Factor With All Losses (%)                             0.4086
# AEP (MWh)                                                   2,149,287.9310
# AEP per kW (MWh/kW)                                                 3.5821
# LCOE ($/MWh)                                                       96.6977
#
#                                                   COE_2022_GF_fixed_bottom  \
# Metrics
# # Turbines                                                         50.0000
# Turbine Rating (MW)                                                12.0000
# Project Capacity (MW)                                             600.0000
# # OSS                                                               1.0000
# Total Export Cable Length (km)                                    118.0680
# Total Array Cable Length (km)                                     277.9831
# FCR (%)                                                             0.0648
# CapEx ($)                                               2,337,324,988.5180
# CapEx per kW ($/kW)                                             3,895.5416
# OpEx ($)                                                1,159,251,631.4665
# OpEx per kW ($/kW)                                              1,932.0861
# Annual OpEx per kW ($/kW)                                          92.0041
# Energy Availability (%)                                             0.9337
# Gross Capacity Factor (%)                                           0.4896
# Net Capacity Factor Without Unmodeled Losses (%)                    0.4572
# Net Capacity Factor With All Losses (%)                             0.4082
# AEP (MWh)                                                   2,147,206.7689
# AEP per kW (MWh/kW)                                                 3.5787
# LCOE ($/MWh)                                                       96.2465
#
#                                                   COE_2022_GF_fixed_bottom  \
# Metrics
# # Turbines                                                         50.0000
# Turbine Rating (MW)                                                12.0000
# Project Capacity (MW)                                             600.0000
# # OSS                                                               1.0000
# Total Export Cable Length (km)                                    118.0680
# Total Array Cable Length (km)                                     277.9831
# FCR (%)                                                             0.0648
# CapEx ($)                                               2,337,324,988.5180
# CapEx per kW ($/kW)                                             3,895.5416
# OpEx ($)                                                1,076,155,234.1886
# OpEx per kW ($/kW)                                              1,793.5921
# Annual OpEx per kW ($/kW)                                          85.4091
# Energy Availability (%)                                             0.9351
# Gross Capacity Factor (%)                                           0.4896
# Net Capacity Factor Without Unmodeled Losses (%)                    0.4577
# Net Capacity Factor With All Losses (%)                             0.4087
# AEP (MWh)                                                   2,149,993.1056
# AEP per kW (MWh/kW)                                                 3.5833
# LCOE ($/MWh)                                                       94.2813
#
#                                                   COE_2022_GF_fixed_bottom  \
# Metrics
# # Turbines                                                         50.0000
# Turbine Rating (MW)                                                12.0000
# Project Capacity (MW)                                             600.0000
# # OSS                                                               1.0000
# Total Export Cable Length (km)                                    118.0680
# Total Array Cable Length (km)                                     277.9831
# FCR (%)                                                             0.0648
# CapEx ($)                                               2,337,324,988.5180
# CapEx per kW ($/kW)                                             3,895.5416
# OpEx ($)                                                1,202,532,094.4568
# OpEx per kW ($/kW)                                              2,004.2202
# Annual OpEx per kW ($/kW)                                          95.4391
# Energy Availability (%)                                             0.9328
# Gross Capacity Factor (%)                                           0.4896
# Net Capacity Factor Without Unmodeled Losses (%)                    0.4567
# Net Capacity Factor With All Losses (%)                             0.4078
# AEP (MWh)                                                   2,144,872.6068
# AEP per kW (MWh/kW)                                                 3.5748
# LCOE ($/MWh)                                                       97.3121
#
#                                                   COE_2022_GF_fixed_bottom  \
# Metrics
# # Turbines                                                         50.0000
# Turbine Rating (MW)                                                12.0000
# Project Capacity (MW)                                             600.0000
# # OSS                                                               1.0000
# Total Export Cable Length (km)                                    118.0680
# Total Array Cable Length (km)                                     277.9831
# FCR (%)                                                             0.0648
# CapEx ($)                                               2,337,324,988.5180
# CapEx per kW ($/kW)                                             3,895.5416
# OpEx ($)                                                1,042,124,404.1733
# OpEx per kW ($/kW)                                              1,736.8740
# Annual OpEx per kW ($/kW)                                          82.7083
# Energy Availability (%)                                             0.9359
# Gross Capacity Factor (%)                                           0.4896
# Net Capacity Factor Without Unmodeled Losses (%)                    0.4582
# Net Capacity Factor With All Losses (%)                             0.4093
# AEP (MWh)                                                   2,152,818.2356
# AEP per kW (MWh/kW)                                                 3.5880
# LCOE ($/MWh)                                                       93.4048
#
#                                                   COE_2022_GF_fixed_bottom  \
# Metrics
# # Turbines                                                         50.0000
# Turbine Rating (MW)                                                12.0000
# Project Capacity (MW)                                             600.0000
# # OSS                                                               1.0000
# Total Export Cable Length (km)                                    118.0680
# Total Array Cable Length (km)                                     277.9831
# FCR (%)                                                             0.0648
# CapEx ($)                                               2,337,324,988.5180
# CapEx per kW ($/kW)                                             3,895.5416
# OpEx ($)                                                1,012,695,288.1937
# OpEx per kW ($/kW)                                              1,687.8255
# Annual OpEx per kW ($/kW)                                          80.3726
# Energy Availability (%)                                             0.9363
# Gross Capacity Factor (%)                                           0.4896
# Net Capacity Factor Without Unmodeled Losses (%)                    0.4585
# Net Capacity Factor With All Losses (%)                             0.4095
# AEP (MWh)                                                   2,153,970.0490
# AEP per kW (MWh/kW)                                                 3.5900
# LCOE ($/MWh)                                                       92.7043
#
#                                                   COE_2022_GF_fixed_bottom  \
# Metrics
# # Turbines                                                         50.0000
# Turbine Rating (MW)                                                12.0000
# Project Capacity (MW)                                             600.0000
# # OSS                                                               1.0000
# Total Export Cable Length (km)                                    118.0680
# Total Array Cable Length (km)                                     277.9831
# FCR (%)                                                             0.0648
# CapEx ($)                                               2,337,324,988.5180
# CapEx per kW ($/kW)                                             3,895.5416
# OpEx ($)                                                1,205,311,057.5657
# OpEx per kW ($/kW)                                              2,008.8518
# Annual OpEx per kW ($/kW)                                          95.6596
# Energy Availability (%)                                             0.9330
# Gross Capacity Factor (%)                                           0.4896
# Net Capacity Factor Without Unmodeled Losses (%)                    0.4568
# Net Capacity Factor With All Losses (%)                             0.4079
# AEP (MWh)                                                   2,145,398.6349
# AEP per kW (MWh/kW)                                                 3.5757
# LCOE ($/MWh)                                                       97.3499
#
#                                                   COE_2022_GF_fixed_bottom  \
# Metrics
# # Turbines                                                         50.0000
# Turbine Rating (MW)                                                12.0000
# Project Capacity (MW)                                             600.0000
# # OSS                                                               1.0000
# Total Export Cable Length (km)                                    118.0680
# Total Array Cable Length (km)                                     277.9831
# FCR (%)                                                             0.0648
# CapEx ($)                                               2,337,324,988.5180
# CapEx per kW ($/kW)                                             3,895.5416
# OpEx ($)                                                1,057,591,323.7519
# OpEx per kW ($/kW)                                              1,762.6522
# Annual OpEx per kW ($/kW)                                          83.9358
# Energy Availability (%)                                             0.9354
# Gross Capacity Factor (%)                                           0.4896
# Net Capacity Factor Without Unmodeled Losses (%)                    0.4581
# Net Capacity Factor With All Losses (%)                             0.4091
# AEP (MWh)                                                   2,151,887.6043
# AEP per kW (MWh/kW)                                                 3.5865
# LCOE ($/MWh)                                                       93.7875
#
#                                                   COE_2022_GF_fixed_bottom  \
# Metrics
# # Turbines                                                         50.0000
# Turbine Rating (MW)                                                12.0000
# Project Capacity (MW)                                             600.0000
# # OSS                                                               1.0000
# Total Export Cable Length (km)                                    118.0680
# Total Array Cable Length (km)                                     277.9831
# FCR (%)                                                             0.0648
# CapEx ($)                                               2,337,324,988.5180
# CapEx per kW ($/kW)                                             3,895.5416
# OpEx ($)                                                1,106,975,665.6259
# OpEx per kW ($/kW)                                              1,844.9594
# Annual OpEx per kW ($/kW)                                          87.8552
# Energy Availability (%)                                             0.9348
# Gross Capacity Factor (%)                                           0.4896
# Net Capacity Factor Without Unmodeled Losses (%)                    0.4576
# Net Capacity Factor With All Losses (%)                             0.4087
# AEP (MWh)                                                   2,149,714.2864
# AEP per kW (MWh/kW)                                                 3.5829
# LCOE ($/MWh)                                                       94.9762
#
#                                                   COE_2022_GF_fixed_bottom
# Metrics
# # Turbines                                                         50.0000
# Turbine Rating (MW)                                                12.0000
# Project Capacity (MW)                                             600.0000
# # OSS                                                               1.0000
# Total Export Cable Length (km)                                    118.0680
# Total Array Cable Length (km)                                     277.9831
# FCR (%)                                                             0.0648
# CapEx ($)                                               2,337,324,988.5180
# CapEx per kW ($/kW)                                             3,895.5416
# OpEx ($)                                                1,253,654,555.3708
# OpEx per kW ($/kW)                                              2,089.4243
# Annual OpEx per kW ($/kW)                                          99.4964
# Energy Availability (%)                                             0.9322
# Gross Capacity Factor (%)                                           0.4896
# Net Capacity Factor Without Unmodeled Losses (%)                    0.4564
# Net Capacity Factor With All Losses (%)                             0.4074
# AEP (MWh)                                                   2,143,194.4675
# AEP per kW (MWh/kW)                                                 3.5720
# LCOE ($/MWh)                                                       98.5242

# %%
summary_results.to_csv('library/results/LCOE_fixed_bottom_10_runs_summary_results.csv')
