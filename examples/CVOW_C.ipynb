# %% [markdown]
# # CVOW-C Working Analysis
#
# This analysis notebook should be considered under construction while assumptions are brought up to date, and the model is refined

# %% [markdown]
# ## TODO List to get this running and accurate
#
# Note: please delete any of the todo items that have been completed, or as they are completed.?
#
# ### ORBIT configuration
#
# - [ ] Do we need to consider exclusions in the layout, or anything else that impacts the cable length calculations?
# - [ ] Why is the array cable installation failing? (currently skipped)
#   - There seems to be an issue with the weather constraints for 10m windspeed <= 25, but the actual windpseeds don't support this error, or at least not seemingly
#   ![image.png](attachment:a0ea1d39-e512-457e-97bf-6f88a83fdbce.png)
#
# ### WOMBAT configuration
#
# - [ ] labor costs need to be recomputed - can use the same
# - [ ] Availability of ~97% is quite high, though ~48% net/gross capacity factor is a bit high, though reasonable, so maybe have replacement events with 100% operating reduction to be a bit more realistic `operation_reduction: 1`
# - [ ] Can we borrow assumptions from the west coast ports work on the failures, etc.?
#   - Aubryn shared a paper with assumptions we should adopt for failures, but they may already exist
#   - [ ] Rob: check on this implementation before we implement it ourselves.
#
# ### FLORIS configuration
#
# - [ ] Check with Paul Fleming/Patrick Duffy on what model combinations we should really be considering here (remove if that's already happend and I'm out of the loop)
#
# ### Financials
# - [ ] Update IRR/NPV to properly account for ORBIT cashflow timing
#
# ### Results
#
# - See bottom for results gathering format

# %% [markdown]
# ## Imports and environment set up

# %%
from pathlib import Path
from itertools import product

import pandas as pd
import matplotlib.pyplot as plt

from whale import Project

pd.options.display.float_format = '{:,.4f}'.format
pd.options.display.max_columns = 100
pd.options.display.max_rows = 100

# %% [markdown]
# ## Determine the configurations and create a Project
#
# **NOTE**: Make sure in the WOMBAT config files that the library path is the same that gets printed in this first code block when you run the notebook

# %%
library_path = Path("library").resolve()
orbit_config = "CVOW_C_base_install.yaml"
wombat_config = "CVOW_C_base_operations.yaml"
floris_config = "CVOW_C_base_floris_jensen.yaml"

# %%
project = Project(

    # Basic Model Configurations
    library_path=library_path,
    weather_profile=library_path / "weather" / "ocean_wind_1_39.0_-74.0_1959_2023.csv",
    orbit_config=orbit_config,
    wombat_config=wombat_config,
    floris_config=floris_config,
    
    # Used for the connecting ORBIT to the weather profile
    orbit_weather_cols=["windspeed_100m", "windspeed_10m", "waveheight"],
    
    # Connecting FLORIS with the weather data and WOMBAT for wind conditions and layout
    floris_windspeed="windspeed_100m",
    floris_wind_direction="wind_direction_100m",
    floris_x_col="floris_x",
    floris_y_col="floris_y",
    
    # Financial Assumptions
    discount_rate=0.025,
    offtake_price=89.06,
    
    # CapEx Date Application Settings
    orbit_start_date="1/1/1998",  # Starting date for installations if set to 0
    # Dates to evenly distribute the varying non-installation CapEx costs per category as
    # (year, month) integer pairs, or a list of tuples, as seen below
    soft_capex_date=(1995, 1), 
    project_capex_date=[(1996, 1), (1996, 7), (1997, 1), (1997, 7)],
    system_capex_date=list(product(range(1996, 2000), (1, 4, 7, 10))), # quarterly over 2 years
    turbine_capex_date=list(product(range(1996, 2000), (1, 4, 7, 10))), # quarterly over 2 years

    # After the first run with a layout file this isn't needed because the default (True) won't fail
    connect_floris_to_layout=True,  # True: connect WOMBAT & FLORIS layout configurations
    connect_orbit_array_design=False,  # True: connect WOMBAT & ORBIT layout configurations
    
)
# Out:
# ORBIT library intialized at 'C:\Users\dmulash\Documents\github\tests_3_10\WHaLE\examples\library'

# %%
# # Run these for the first iteration only

# # Calculate the relative distance FLORIS layout
# project.generate_floris_positions_from_layout(
#     x_col="easting",
#     y_col="northing",
#     update_config=True,  # update the model and configuration
#     config_fname=floris_config,  # save over the original
# )
# project.connect_floris_to_turbines(x_col="floris_x", y_col="floris_y")

# # Once ORBIT issues are resolved, and feature branch is merged into develop this can be used
# project.connect_orbit_cable_lengths()

# %% [markdown]
# ![image.png](attachment:f1667de5-de3e-4508-8f0b-b757b43b53cd.png)

# %%
# Inspect the layout
fig, ax = project.plot_farm(return_fig=True)
# fig.savefig(library_path / "results" / "ocean_wind_1_layout.svg")

# %% [markdown]
# ## Run the analyses and calculate results
#
# This separately calls the `run` methods for each of the ORBIT `ProjectManager` and WOMBAT `Simualation`, in that order. Alternatively, these could just be called on their own, just like we must with FLORIS for the time being.
#
# **NOTE: Array Cable installation is commented out in the configuration for a `StateExhausted` error I can't figure out.**

# %%
project.run(
    which_floris="wind_rose",
    full_wind_rose=False,
    floris_reinitialize_kwargs=dict(cut_in_wind_speed=3.0, cut_out_wind_speed=25.0)
)
# Out:
# UserWarning: C:\Users\dmulash\.conda\envs\whale\lib\site-packages\ORBIT\phases\design\array_system_design.py:906
# Missing data in columns ['bury_speed']; all values will be calculated.
# ---------------------------------------------------------------------------
# StateExhausted                            Traceback (most recent call last)
# File ~\.conda\envs\whale\lib\site-packages\marmot\agent.py:106, in Agent.task(self, name, duration, constraints, suspendable, **kwargs)
#     105     e.agent = self
# --> 106     raise e
#     108 if len(durations) % 2 != 0:
#
# File ~\.conda\envs\whale\lib\site-packages\marmot\agent.py:102, in Agent.task(self, name, duration, constraints, suspendable, **kwargs)
#     101 try:
# --> 102     durations = self.env.calculate_operational_delays(duration, constraints)
#     104 except StateExhausted as e:
#
# File ~\.conda\envs\whale\lib\site-packages\marmot\environment.py:211, in Environment.calculate_operational_delays(self, n, constraints)
#     210 if durations is None:
# --> 211     raise StateExhausted(len(self._state), **valid)
#     213 return durations
#
# StateExhausted: 'Array Cable Installation Vessel': State data exhausted at element 219,451.
# 		'waveheight <= 2.0'
# 		'windspeed_10m <= 25'
#
# The above exception was the direct cause of the following exception:
#
# StateExhausted                            Traceback (most recent call last)
# File ~\.conda\envs\whale\lib\site-packages\ORBIT\core\vessel.py:91, in Vessel.task_wrapper(self, name, duration, constraints, suspendable, **kwargs)
#      90 duration /= self.avail
# ---> 91 yield self.task(name, duration, constraints, suspendable, **kwargs)
#
# StateExhausted: State data exhausted at element 219,451.
#
# The above exception was the direct cause of the following exception:
#
# StateExhausted                            Traceback (most recent call last)
# File ~\.conda\envs\whale\lib\site-packages\ORBIT\phases\install\cable_install\common.py:183, in lay_bury_cable(vessel, distance, **kwargs)
#     181 lay_bury_time = distance / lay_bury_speed
# --> 183 yield vessel.task_wrapper(
#     184     "Lay/Bury Cable",
#     185     lay_bury_time,
#     186     constraints=vessel.operational_limits,
#     187     suspendable=True,
#     188     **kwargs,
#     189 )
#
# StateExhausted: State data exhausted at element 219,451.
#
# The above exception was the direct cause of the following exception:
#
# StateExhausted                            Traceback (most recent call last)
# File ~\.conda\envs\whale\lib\site-packages\ORBIT\phases\install\cable_install\array.py:314, in install_array_cables(vessel, distance, cable_data, num_strings, burial_vessel, trench_vessel, free_cable_length, **kwargs)
#     313 if burial_vessel is None:
# --> 314     yield lay_bury_cable(vessel, section, **specs)
#     315     installed += section
#
# StateExhausted: State data exhausted at element 219,451.
#
# The above exception was the direct cause of the following exception:
#
# StateExhausted                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 project.run(
#       2     which_floris="wind_rose",
#       3     full_wind_rose=False,
#       4     floris_reinitialize_kwargs=dict(cut_in_wind_speed=3.0, cut_out_wind_speed=25.0)
#       5 )
#
# File ~\Documents\github\tests_3_10\WHaLE\whale\project.py:934, in Project.run(self, which_floris, floris_reinitialize_kwargs, floris_run_kwargs, full_wind_rose, skip, cut_in_wind_speed, cut_out_wind_speed, nodes)
#     929     floris_reinitialize_kwargs.update(
#     930         {"cut_in_wind_speed": cut_in_wind_speed, "cut_out_wind_speed": cut_out_wind_speed}
#     931     )
#     933 if "orbit" not in skip:
# --> 934     self.orbit.run()
#     935 if "wombat" not in skip:
#     936     self.wombat.run()
#
# File ~\.conda\envs\whale\lib\site-packages\ORBIT\manager.py:162, in ProjectManager.run(self, **kwargs)
#     159     self.run_multiple_phases_in_serial(install_phases, **kwargs)
#     161 elif isinstance(install_phases, dict):
# --> 162     self.run_multiple_phases_overlapping(install_phases, **kwargs)
#     164 if install_phases:
#     165     self.progress = ProjectProgress(self.progress_logs)
#
# File ~\.conda\envs\whale\lib\site-packages\ORBIT\manager.py:697, in ProjectManager.run_multiple_phases_overlapping(self, phases, **kwargs)
#     694 # Run defined
#     695 for name, start in defined.items():
# --> 697     _, logs = self.run_install_phase(name, start, **kwargs)
#     699     if logs is None:
#     700         continue
#
# File ~\.conda\envs\whale\lib\site-packages\ORBIT\manager.py:559, in ProjectManager.run_install_phase(self, name, start, **kwargs)
#     557 else:
#     558     phase = _class(_config, weather=weather, phase_name=name, **kwargs)
# --> 559     phase.run()
#     561 self._phases[name] = phase
#     563 time = phase.total_phase_time
#
# File ~\.conda\envs\whale\lib\site-packages\ORBIT\phases\install\install_phase.py:104, in InstallPhase.run(self, until)
#      94 """
#      95 Runs the simulation on self.env.
#      96
#    (...)
#     100     Number of steps to run.
#     101 """
#     103 self.env._submit_log({"message": "SIMULATION START"}, "DEBUG")
# --> 104 self.env.run(until=until)
#     105 self.append_phase_info()
#     106 self.env._submit_log({"message": "SIMULATION END"}, "DEBUG")
#
# File ~\.conda\envs\whale\lib\site-packages\_simpy\core.py:142, in BaseEnvironment.run(self, until)
#     140 try:
#     141     while True:
# --> 142         self.step()
#     143 except StopSimulation as exc:
#     144     return exc.args[0]  # == until.value
#
# File ~\.conda\envs\whale\lib\site-packages\_simpy\core.py:243, in Environment.step(self)
#     241 exc = type(event._value)(*event._value.args)
#     242 exc.__cause__ = event._value
# --> 243 raise exc
#
# StateExhausted: State data exhausted at element 219,451.

# %%
metrics_configuration = {
    "# Turbines": {"metric": "n_turbines", "kwargs": {}},
    "Turbine Rating (MW)": {"metric": "turbine_rating", "kwargs": {}},
    "# OSS": {"metric": "n_substations", "kwargs": {}},
    "Total Export Cable Length (km)": {"metric": "export_system_total_cable_length", "kwargs": {}},
    "Total Array Cable Length (km)": {"metric": "array_system_total_cable_length", "kwargs": {}},
    "CapEx ($)": {"metric": "capex", "kwargs": {}},
    "CapEx per kW ($/kW)": {"metric": "capex", "kwargs": {"per_capacity": "kw"}},
    "OpEx ($)": {"metric": "opex", "kwargs": {}},
    "OpEx per kW ($/kW)": {"metric": "opex", "kwargs": {"per_capacity": "kw"}},
    "AEP (MWh)": {"metric": "energy_production", "kwargs": {}},
    "AEP per kW (MWh/kW)": {"metric": "energy_production", "kwargs": {"per_capacity": "kw"}},
    "LCOE ($/kWh)": {"metric": "lcoe", "kwargs": {"units": "kw"}},
    "IRR ($)": {"metric": "irr", "kwargs": {}},
    "NPV ($)": {"metric": "npv", "kwargs": {}},
}

report_df = project.generate_report(metrics_configuration, "Ocean Wind 1")

# %% [markdown]
# ## Results
#
# This dataframe can be appended to an existing results file if desired, as long as the column naming conventions remain the same across projects.

# %%
report_df

# %%
report_df.T
